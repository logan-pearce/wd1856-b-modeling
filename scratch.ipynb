# %%
from myastrotools.reflectx import GetP
p = GetP(sheet_id='1BQH36n5O2Kq8iB1ZmM_WNu1RsRVLRpG64ACdKaDYueg', 
             sheet_name='WD1856b-BaseModelGrid')
p
# Out:
#         name              output_dir   rstar   a/Rs  Teq  pl_mass  pl_rad  \
# 0    WD1856b  /data2/lpearce/wd1856b  0.0131  382.5  163        1    10.4
# 1    WD1856b  /data2/lpearce/wd1856b  0.0131  382.5  163        2    10.4
# 2    WD1856b  /data2/lpearce/wd1856b  0.0131  382.5  163        4    10.4
# 3    WD1856b  /data2/lpearce/wd1856b  0.0131  382.5  163        8    10.4
# 4    WD1856b  /data2/lpearce/wd1856b  0.0131  382.5  163       12    10.4
# ..       ...                     ...     ...    ...  ...      ...     ...
# 395  WD1856b  /data2/lpearce/wd1856b  0.0131  382.5  163        1    10.4
# 396  WD1856b  /data2/lpearce/wd1856b  0.0131  382.5  163        2    10.4
# 397  WD1856b  /data2/lpearce/wd1856b  0.0131  382.5  163        4    10.4
# 398  WD1856b  /data2/lpearce/wd1856b  0.0131  382.5  163        8    10.4
# 399  WD1856b  /data2/lpearce/wd1856b  0.0131  382.5  163       12    10.4
#
#       mh  mh_str   cto  ...  rfacv  noTiOVO  nstr_upper  nstr_deep  nlevel  \
# ...

# %%
range(len(p))
# Out:
# range(0, 400)
